# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn

import torch.optim as optim

import itertools
import random

import argparse
import tqdm


import torch
import numpy as np
from scipy import linalg

import glob
import cv2
import torch
import torchaudio
import torchaudio.functional as F
import torchaudio.transforms as T
from scipy.signal import find_peaks


## Recall Function
def top_k_recall(similarity_matrix, k):
    """
    Compute top-k recall from a similarity matrix (vectorized version).

    similarity_matrix: Tensor of shape (batch_size, batch_size), where
                       diagonal elements represent positive pairs.
    k: The value of k for top-k recall.

    Returns:
        recall: The top-k recall (mean recall across all examples).
    """
    batch_size = similarity_matrix.size(0)

    # Get the indices of the top-k most similar items for each row (video/audio example)
    _, top_k_indices = torch.topk(similarity_matrix, k, dim=1)

    # Create a tensor for diagonal indices (i, i) for each row
    diagonal_indices = torch.arange(batch_size, device=similarity_matrix.device)

    # Check if the diagonal index of each row is in the top-K indices of that row
    # `top_k_indices` is of shape (batch_size, k)
    is_true_positive_in_top_k = (top_k_indices == diagonal_indices.unsqueeze(1))

    # Calculate recall: for each row, check if the diagonal index is in the top-K
    recall_per_row = is_true_positive_in_top_k.any(dim=1).float()

    # Return the mean recall across all examples (rows)
    return recall_per_row.mean()


### FAD Function
def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    """Calculate the Fréchet Distance between two multivariate Gaussians."""
    mu1 = mu1.cpu().numpy()
    mu2 = mu2.cpu().numpy()
    sigma1 = sigma1.cpu().numpy()
    sigma2 = sigma2.cpu().numpy()

    diff = mu1 - mu2

    covmean, _ = linalg.sqrtm(sigma1 @ sigma2, disp=False)
    if not np.isfinite(covmean).all():
        print("Adding epsilon to diagonal of covariance matrices for stability.")
        sigma1 += np.eye(sigma1.shape[0]) * eps
        sigma2 += np.eye(sigma2.shape[0]) * eps
        covmean = linalg.sqrtm(sigma1 @ sigma2)

    # Numerical error might give slight imaginary part
    if np.iscomplexobj(covmean):
        covmean = covmean.real

    tr_covmean = np.trace(covmean)

    distance = (diff @ diff) + np.trace(sigma1) + np.trace(sigma2) - 2 * tr_covmean
    return torch.tensor(distance, dtype=torch.float32)


def compute_fad(real_embeddings, retrieved_embeddings):
    """Compute FAD between real and generated embeddings."""
    mu_real = real_embeddings.mean(dim=0)
    sigma_real = torch.cov(real_embeddings.T)

    mu_gen = retrieved_embeddings.mean(dim=0)
    sigma_gen = torch.cov(retrieved_embeddings.T)

    fad = calculate_frechet_distance(mu_real, sigma_real, mu_gen, sigma_gen)
    return fad


def detect_video_peaks(frames, fps, threshold=1, distance=3):
    """
    Detect motion peaks using optical flow and find_peaks.
    
    Args:
        frames: list of grayscale frames
        fps: frames per second (adjusted for skipping)
        threshold: minimum peak height (motion strength)
        distance: minimum number of frames between peaks

    Returns:
        flow_trajectory: List of average flow magnitudes
        peak_times: Timestamps of detected peaks (in seconds)
    """
    distance = distance * fps
    # Compute optical flow magnitudes between consecutive frames
    flow_trajectory = [
        compute_of(frames[i - 1], frames[i])
        for i in range(1, len(frames))
    ]

    # Use scipy to detect peaks
    peak_indices, properties = find_peaks(
        flow_trajectory,
        height=threshold,       # Minimum motion strength
        distance=distance       # Minimum distance between peaks
    )

    # Convert frame indices to time
    peak_times = [idx / fps for idx in peak_indices]

    return flow_trajectory, peak_times


def extract_frames(video_path, frame_skip=5, downsample_factor=2, max_frames=360):
    """Extract grayscale, downsampled frames from video with frame skipping."""
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError(f"Error: Unable to open video {video_path}.")

    original_fps = cap.get(cv2.CAP_PROP_FPS)
    max_frames = max_frames*original_fps
    frames = []
    frame_idx = 0

    while True:
        success, frame = cap.read()
        if not success:
            break
        if frame_idx % frame_skip == 0:
            if downsample_factor > 1:
                h, w = frame.shape[:2]
                frame = cv2.resize(frame, (w // downsample_factor, h // downsample_factor))
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            frames.append(gray)
        frame_idx += 1
        if frame_idx > max_frames:
            break
    cap.release()

    effective_fps = original_fps / frame_skip
    return frames, effective_fps

def detect_audio_peaks(audio_file):
    waveform, sr = torchaudio.load(audio_file)
    waveform = waveform.mean(dim=0)  # Convert to mono

    # Compute the short-time energy
    frame_length = int(0.025 * sr)  # 25ms frames
    hop_length = int(0.010 * sr)    # 10ms hop

    energy = waveform.unfold(0, frame_length, hop_length).pow(2).mean(dim=1)

    # Normalize energy
    energy = (energy - energy.min()) / (energy.max() - energy.min() + 1e-6)

    # Detect peaks: simple threshold
    peaks = (energy[1:-1] > energy[:-2]) & (energy[1:-1] > energy[2:]) & (energy[1:-1] > 0.3)
    peak_indices = torch.nonzero(peaks).squeeze() + 1  # +1 because of slicing

    onset_times = (peak_indices * hop_length) / sr
    return onset_times.tolist()


# Function to find local maxima with threshold
def find_local_max_indexes(arr, fps):
    arr = torch.tensor(arr)
    local_max_mask = (arr[1:-1] > arr[:-2]) & (arr[1:-1] > arr[2:]) & (arr[1:-1] >= 0.5)
    indexes = torch.where(local_max_mask)[0] + 1  # offset by 1 due to slicing
    times = indexes.float() / fps
    return times.tolist()

# Function to compute the optical flow magnitude between two frames
def compute_of(prev_gray, curr_gray):
    flow = cv2.calcOpticalFlowFarneback(prev_gray, curr_gray, None,
                                        0.5, 3, 15, 3, 5, 1.2, 0)
    magnitude = cv2.magnitude(flow[..., 0], flow[..., 1])
    avg_magnitude = magnitude.mean()
    return avg_magnitude

# Function to detect video peaks
def detect_video_peaks(frames, fps):
    flow_trajectory = [
        compute_of(frames[i-1], frames[i])
        for i in range(1, len(frames))
    ]
    video_peaks = find_local_max_indexes(flow_trajectory, fps)
    return flow_trajectory, video_peaks

# Function to calculate Intersection over Union (IoU)
def calc_intersection_over_union(audio_peaks, video_peaks, fps):
    intersection_length = 0
    used_video_peaks = [False] * len(video_peaks)
    for audio_peak in audio_peaks:
        for j, video_peak in enumerate(video_peaks):
            if not used_video_peaks[j] and abs(video_peak - audio_peak) <= (1 / fps):
                intersection_length += 1
                used_video_peaks[j] = True
                break
    union = len(audio_peaks) + len(video_peaks) - intersection_length
    return intersection_length / union if union > 0 else 0

# %%
test_path = '/work/users/s/m/smerrill/Youtube8m/test_resnet.csv'
vid_path = '/work/users/s/m/smerrill/Youtube8m/video'
aud_path = '/work/users/s/m/smerrill/Youtube8m/audio'

# %%
video_files = os.listdir(vid_path)
audio_files = os.listdir(aud_path)

# %%
# Open and read the CSV file
with open(test_path, 'r') as file:
    lines = file.readlines()
test_ids = [line.replace('.npy\n', '') for line in lines]

# %%
test_vid_files = []
for video_file in video_files:
    tmp = video_file.split('.')[0]
    
    if tmp in test_ids:
        test_vid_files.append(os.path.join(vid_path, video_file))

# %%
test_aud_files = []
for audio_file in audio_files:
    tmp = audio_file.split('.')[0]
    
    if tmp in test_ids:
        test_aud_files.append(os.path.join(aud_path, audio_file))

# %%
os.makedirs('/work/users/s/m/smerrill/SymMV/video_peaks/')
os.makedirs('/work/users/s/m/smerrill/SymMV/audio_peaks/')
os.makedirs('/work/users/s/m/smerrill/Youtube8m/video_peaks/')
os.makedirs('/work/users/s/m/smerrill/Youtube8m/audio_peaks/')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 os.makedirs('/work/users/s/m/smerrill/SymMV/video_peaks/')
#       2 os.makedirs('/work/users/s/m/smerrill/SymMV/audio_peaks/')
#       3 os.makedirs('/work/users/s/m/smerrill/Youtube8m/video_peaks/')
#
# File ~/.conda/envs/video_features/lib/python3.13/os.py:227, in makedirs(name, mode, exist_ok)
#     225         return
#     226 try:
# --> 227     mkdir(name, mode)
#     228 except OSError:
#     229     # Cannot rely on checking for EEXIST, since the operating system
#     230     # could give priority to other errors like EACCES or EROFS
#     231     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [Errno 17] File exists: '/work/users/s/m/smerrill/SymMV/video_peaks/'

# %%
for i in range(len(video_files)):
    try:
        vid_file = test_vid_files[i]
        aud_file = test_aud_files[i]
        print(i, vid_file, aud_file)
        vid_save_path = vid_file.replace('video', 'video_peaks').split('.')[0] + '.npy'
        aud_save_path = aud_file.replace('audio', 'audio_peaks').split('.')[0] + '.npy'
        
        #if os.path.isfile(aud_save_path):
        #    print(f"SKIPPING {vid_file}")
        #    continue

        frames, fps = extract_frames(vid_file, frame_skip=5, downsample_factor=2)
        _, video_peaks = detect_video_peaks(frames, fps)
        audio_peaks = detect_audio_peaks(aud_file)
        
        np.save(vid_save_path, video_peaks)
        np.save(aud_save_path, audio_peaks)
        
    except Exception as e:
        print(i, e)
        continue
# Out:
# 0 /work/users/s/m/smerrill/Youtube8m/video/--SM0mwlHjY.mp4 /work/users/s/m/smerrill/Youtube8m/audio/--SM0mwlHjY.mp3
# 1 /work/users/s/m/smerrill/Youtube8m/video/-63Da0zOWWo.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-63Da0zOWWo.mp3
# 2 /work/users/s/m/smerrill/Youtube8m/video/-6jwBiRsWP0.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-6jwBiRsWP0.mp3
# 3 /work/users/s/m/smerrill/Youtube8m/video/-AICqjB56gE.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-AICqjB56gE.mp3
# 4 /work/users/s/m/smerrill/Youtube8m/video/-DNnvpMjq9g.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-DNnvpMjq9g.mp3
# 5 /work/users/s/m/smerrill/Youtube8m/video/-IdR0ifDCUE.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-IdR0ifDCUE.mp3
# 6 /work/users/s/m/smerrill/Youtube8m/video/-L-I2wzV5Ss.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-L-I2wzV5Ss.mp3
# 7 /work/users/s/m/smerrill/Youtube8m/video/-MLECADky0c.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-MLECADky0c.mp3
# 8 /work/users/s/m/smerrill/Youtube8m/video/-O_jcpg7Fns.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-O_jcpg7Fns.mp3
# 9 /work/users/s/m/smerrill/Youtube8m/video/-SeciVrlYXM.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-SeciVrlYXM.mp3
# 10 /work/users/s/m/smerrill/Youtube8m/video/-TUyoyD6FZY.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-TUyoyD6FZY.mp3
# 11 /work/users/s/m/smerrill/Youtube8m/video/-VuZAC9UMaY.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-VuZAC9UMaY.mp3
# 12 /work/users/s/m/smerrill/Youtube8m/video/-b0hV-X1hTs.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-b0hV-X1hTs.mp3
# 13 /work/users/s/m/smerrill/Youtube8m/video/-bbxT3XtT38.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-bbxT3XtT38.mp3
# 14 /work/users/s/m/smerrill/Youtube8m/video/-jGbCXemBQM.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-jGbCXemBQM.mp3
# 15 /work/users/s/m/smerrill/Youtube8m/video/-kArMkRwSE4.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-kArMkRwSE4.mp3
# 16 /work/users/s/m/smerrill/Youtube8m/video/-lYN2nlMy64.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-lYN2nlMy64.mp3
# 17 /work/users/s/m/smerrill/Youtube8m/video/-swNoC58fxE.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-swNoC58fxE.mp3
# 18 /work/users/s/m/smerrill/Youtube8m/video/-tIZhqLk6uQ.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-tIZhqLk6uQ.mp3
# 19 /work/users/s/m/smerrill/Youtube8m/video/-tpBEjaEZ1o.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-tpBEjaEZ1o.mp3
# 20 /work/users/s/m/smerrill/Youtube8m/video/-yYH2CrmYGM.mp4 /work/users/s/m/smerrill/Youtube8m/audio/-yYH2CrmYGM.mp3
# 21 /work/users/s/m/smerrill/Youtube8m/video/02wANV-plPg.mp4 /work/users/s/m/smerrill/Youtube8m/audio/02wANV-plPg.mp3
# 22 /work/users/s/m/smerrill/Youtube8m/video/07JiEGgjFE4.mp4 /work/users/s/m/smerrill/Youtube8m/audio/07JiEGgjFE4.webm
# 23 /work/users/s/m/smerrill/Youtube8m/video/09IlmY3Os8A.mp4 /work/users/s/m/smerrill/Youtube8m/audio/09IlmY3Os8A.mp3
# 24 /work/users/s/m/smerrill/Youtube8m/video/0BN0HkUpemc.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0BN0HkUpemc.mp3
# 25 /work/users/s/m/smerrill/Youtube8m/video/0ElHhngPx1U.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0ElHhngPx1U.mp3
# 26 /work/users/s/m/smerrill/Youtube8m/video/0FFdsKrNg70.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0FFdsKrNg70.mp3
# 27 /work/users/s/m/smerrill/Youtube8m/video/0FgA3tmQ4e4.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0FgA3tmQ4e4.mp3
# 28 /work/users/s/m/smerrill/Youtube8m/video/0H7jeANylxU.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0H7jeANylxU.mp3
# 29 /work/users/s/m/smerrill/Youtube8m/video/0NcRKe6x6SQ.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0NcRKe6x6SQ.mp3
# 30 /work/users/s/m/smerrill/Youtube8m/video/0QlGva4NRQ4.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0QlGva4NRQ4.mp3
# 31 /work/users/s/m/smerrill/Youtube8m/video/0SbKwqK7ick.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0SbKwqK7ick.webm
# 32 /work/users/s/m/smerrill/Youtube8m/video/0UVF6Q2WrAI.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0UVF6Q2WrAI.mp3
# 33 /work/users/s/m/smerrill/Youtube8m/video/0Ub_Gem73ak.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0Ub_Gem73ak.mp3
# 34 /work/users/s/m/smerrill/Youtube8m/video/0ZXDFLPqkf0.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0ZXDFLPqkf0.mp3
# 35 /work/users/s/m/smerrill/Youtube8m/video/0h3albh-ngU.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0h3albh-ngU.mp3
# 36 /work/users/s/m/smerrill/Youtube8m/video/0kxc-Iqq-wk.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0kxc-Iqq-wk.webm
# 37 /work/users/s/m/smerrill/Youtube8m/video/0lqv7UTIqm0.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0lqv7UTIqm0.mp3
# 38 /work/users/s/m/smerrill/Youtube8m/video/0nDDrMUm0nU.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0nDDrMUm0nU.mp3
# 39 /work/users/s/m/smerrill/Youtube8m/video/0nn1kwp6F0A.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0nn1kwp6F0A.mp3
# 40 /work/users/s/m/smerrill/Youtube8m/video/0oMOdxqV7C4.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0oMOdxqV7C4.mp3
# 41 /work/users/s/m/smerrill/Youtube8m/video/0p9rs1R4EBk.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0p9rs1R4EBk.webm
# 42 /work/users/s/m/smerrill/Youtube8m/video/0u_EIpIf0r8.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0u_EIpIf0r8.mp3
# 43 /work/users/s/m/smerrill/Youtube8m/video/0wWoge2loIA.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0wWoge2loIA.mp3
# 44 /work/users/s/m/smerrill/Youtube8m/video/0y8AEEyS20Q.mp4 /work/users/s/m/smerrill/Youtube8m/audio/0y8AEEyS20Q.mp3
# 45 /work/users/s/m/smerrill/Youtube8m/video/1-1dUKYuFAo.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1-1dUKYuFAo.webm
# 46 /work/users/s/m/smerrill/Youtube8m/video/1-ZbL5t25vE.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1-ZbL5t25vE.mp3
# 47 /work/users/s/m/smerrill/Youtube8m/video/1-hzfYfmTxo.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1-hzfYfmTxo.webm
# 48 /work/users/s/m/smerrill/Youtube8m/video/1-pTljZgJMY.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1-pTljZgJMY.mp3
# 49 /work/users/s/m/smerrill/Youtube8m/video/185R9dSnp_c.mp4 /work/users/s/m/smerrill/Youtube8m/audio/185R9dSnp_c.mp3
# 50 /work/users/s/m/smerrill/Youtube8m/video/1B0k-Os59tA.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1B0k-Os59tA.mp4
# 51 /work/users/s/m/smerrill/Youtube8m/video/1FUdFLAcCWE.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1FUdFLAcCWE.m4a
# 52 /work/users/s/m/smerrill/Youtube8m/video/1PIzjq_ADc4.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1PIzjq_ADc4.mp3
# 53 /work/users/s/m/smerrill/Youtube8m/video/1PklcaF07I4.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1PklcaF07I4.mp3
# 54 /work/users/s/m/smerrill/Youtube8m/video/1_cvaZuUsAA.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1_cvaZuUsAA.mp3
# 55 /work/users/s/m/smerrill/Youtube8m/video/1arX3sF2-fk.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1arX3sF2-fk.webm
# 56 /work/users/s/m/smerrill/Youtube8m/video/1dowhVKeupc.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1dowhVKeupc.mp3
# 57 /work/users/s/m/smerrill/Youtube8m/video/1iyTPqAuKEs.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1iyTPqAuKEs.mp3
# 58 /work/users/s/m/smerrill/Youtube8m/video/1oH_zHqNt9w.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1oH_zHqNt9w.mp3
# 59 /work/users/s/m/smerrill/Youtube8m/video/1r9ghI7YcL0.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1r9ghI7YcL0.mp3
# 60 /work/users/s/m/smerrill/Youtube8m/video/1xeE9s2cKm4.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1xeE9s2cKm4.mp3
# 61 /work/users/s/m/smerrill/Youtube8m/video/1yngR5EW-bI.mp4 /work/users/s/m/smerrill/Youtube8m/audio/1yngR5EW-bI.mp3
# 62 /work/users/s/m/smerrill/Youtube8m/video/26apH8kCu1E.mp4 /work/users/s/m/smerrill/Youtube8m/audio/26apH8kCu1E.webm
# 63 /work/users/s/m/smerrill/Youtube8m/video/27pgbjNR-c0.mp4 /work/users/s/m/smerrill/Youtube8m/audio/27pgbjNR-c0.mp3
# 64 /work/users/s/m/smerrill/Youtube8m/video/29pQZBp1MCY.mp4 /work/users/s/m/smerrill/Youtube8m/audio/29pQZBp1MCY.mp3
# 65 /work/users/s/m/smerrill/Youtube8m/video/2AnokNmSBsI.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2AnokNmSBsI.webm
# 66 /work/users/s/m/smerrill/Youtube8m/video/2BLs3jUsEYE.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2BLs3jUsEYE.mp3
# 67 /work/users/s/m/smerrill/Youtube8m/video/2CGE6HFE87Y.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2CGE6HFE87Y.mp3
# 68 /work/users/s/m/smerrill/Youtube8m/video/2DJIe9DnaCU.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2DJIe9DnaCU.mp3
# 69 /work/users/s/m/smerrill/Youtube8m/video/2FHQLXpuh_U.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2FHQLXpuh_U.mp3
# 70 /work/users/s/m/smerrill/Youtube8m/video/2GjYMSzzALU.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2GjYMSzzALU.mp3
# 71 /work/users/s/m/smerrill/Youtube8m/video/2HRm35ESUKw.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2HRm35ESUKw.mp3
# 72 /work/users/s/m/smerrill/Youtube8m/video/2Myk6X_glgk.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2Myk6X_glgk.mp3
# 73 /work/users/s/m/smerrill/Youtube8m/video/2WHNs7SGNxI.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2WHNs7SGNxI.mp3
# 74 /work/users/s/m/smerrill/Youtube8m/video/2ZHLMmZB-HQ.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2ZHLMmZB-HQ.mp3
# 75 /work/users/s/m/smerrill/Youtube8m/video/2_5ozT8Q_xE.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2_5ozT8Q_xE.mp3
# 76 /work/users/s/m/smerrill/Youtube8m/video/2c5RGk2CWbo.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2c5RGk2CWbo.mp4
# 77 /work/users/s/m/smerrill/Youtube8m/video/2gl0fb5NcEA.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2c5RGk2CWbo.webm
# 78 /work/users/s/m/smerrill/Youtube8m/video/2lAcXk5IaIc.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2gl0fb5NcEA.mp3
# 79 /work/users/s/m/smerrill/Youtube8m/video/2n4h9pMnykc.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2lAcXk5IaIc.mp3
# 80 /work/users/s/m/smerrill/Youtube8m/video/2pIZHUY5eFg.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2n4h9pMnykc.mp3
# 81 /work/users/s/m/smerrill/Youtube8m/video/2r4308s7t7U.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2pIZHUY5eFg.mp3
# 82 /work/users/s/m/smerrill/Youtube8m/video/2y9J2Pee6OU.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2r4308s7t7U.mp3
# 83 /work/users/s/m/smerrill/Youtube8m/video/2zA0vjXX6Rw.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2y9J2Pee6OU.mp3
# 84 /work/users/s/m/smerrill/Youtube8m/video/36n4yn0nX3A.mp4 /work/users/s/m/smerrill/Youtube8m/audio/2zA0vjXX6Rw.mp3
# KeyboardInterrupt
#
#
# KeyboardInterrupt

# %%
frames, fps = extract_frames(vid_file, frame_skip=2, downsample_factor=2)

_, video_peaks = detect_video_peaks(frames, fps)

# %%
video_peaks
# Out:
# [0.06666667014360428,
#  0.4000000059604645,
#  0.6000000238418579,
#  0.8666666746139526,
#  1.1333333253860474,
#  1.2666666507720947,
#  1.4666666984558105,
#  1.6666666269302368,
#  1.9333332777023315,
#  2.200000047683716,
#  2.3333332538604736,
#  2.5999999046325684,
#  2.799999952316284,
#  3.0,
#  3.3333332538604736,
#  3.6666667461395264,
#  3.799999952316284,
#  4.0,
#  4.266666889190674,
#  4.4666666984558105,
#  5.199999809265137,
#  6.199999809265137,
#  7.133333206176758,
#  7.266666889190674,
#  7.400000095367432,
#  7.5333333015441895,
#  7.666666507720947,
#  7.866666793823242,
#  8.133333206176758,
#  8.399999618530273,
#  8.533333778381348,
#  8.666666984558105,
#  8.933333396911621,
#  9.133333206176758,
#  9.399999618530273,
#  9.600000381469727,
#  9.866666793823242,
#  10.066666603088379,
#  10.399999618530273,
#  10.600000381469727,
#  10.866666793823242,
#  11.0,
#  11.399999618530273,
#  11.600000381469727,
#  11.733333587646484,
#  11.866666793823242,
#  12.933333396911621,
#  13.199999809265137,
#  13.800000190734863,
#  14.066666603088379,
#  14.399999618530273,
#  14.600000381469727,
#  14.800000190734863,
#  15.066666603088379,
#  15.266666412353516,
#  15.466666221618652,
#  15.600000381469727,
#  15.800000190734863,
#  16.133333206176758,
#  16.399999618530273,
#  16.600000381469727,
#  16.799999237060547,
#  16.933332443237305,
#  17.066667556762695,
#  17.266666412353516,
#  17.46666717529297,
#  17.600000381469727,
#  17.799999237060547,
#  17.933332443237305,
#  18.133333206176758,
#  18.266666412353516,
#  18.46666717529297,
#  18.600000381469727,
#  18.799999237060547,
#  18.933332443237305,
#  19.066667556762695,
#  19.266666412353516,
#  19.399999618530273,
#  19.600000381469727,
#  19.799999237060547,
#  19.933332443237305,
#  20.066667556762695,
#  20.266666412353516,
#  20.399999618530273,
#  20.799999237060547,
#  20.933332443237305,
#  21.133333206176758,
#  21.266666412353516,
#  21.399999618530273,
#  21.799999237060547,
#  21.933332443237305,
#  22.133333206176758,
#  22.33333396911621,
#  22.46666717529297,
#  22.600000381469727,
#  22.733333587646484,
#  22.933332443237305,
#  23.066667556762695,
#  23.200000762939453,
#  23.399999618530273,
#  23.53333282470703,
#  23.733333587646484,
#  23.933332443237305,
#  24.066667556762695,
#  24.200000762939453,
#  24.399999618530273,
#  24.53333282470703,
#  24.733333587646484,
#  24.933332443237305,
#  25.066667556762695,
#  25.266666412353516,
#  25.399999618530273,
#  25.600000381469727,
#  25.733333587646484,
#  25.866666793823242,
#  26.066667556762695,
#  26.266666412353516,
#  26.46666717529297,
#  26.600000381469727,
#  26.933332443237305,
#  27.066667556762695,
#  27.266666412353516,
#  27.399999618530273,
#  27.600000381469727,
#  27.733333587646484,
#  27.866666793823242,
#  28.0,
#  28.133333206176758,
#  28.266666412353516,
#  28.399999618530273,
#  28.53333282470703,
#  28.733333587646484,
#  28.866666793823242,
#  29.066667556762695,
#  29.266666412353516,
#  29.399999618530273,
#  29.53333282470703,
#  29.733333587646484,
#  30.066667556762695,
#  30.33333396911621,
#  30.600000381469727,
#  30.799999237060547,
#  31.066667556762695,
#  31.33333396911621,
#  31.53333282470703,
#  31.733333587646484,
#  32.0,
#  32.266666412353516,
#  32.66666793823242,
#  32.86666488647461,
#  33.13333511352539,
#  33.46666717529297,
#  33.733333587646484,
#  33.93333435058594,
#  34.13333511352539,
#  34.53333282470703,
#  34.733333587646484,
#  34.93333435058594,
#  35.20000076293945,
#  35.400001525878906,
#  35.66666793823242,
#  36.0,
#  36.20000076293945,
#  36.400001525878906,
#  36.53333282470703,
#  36.93333435058594,
#  37.20000076293945,
#  37.33333206176758,
#  37.53333282470703,
#  37.733333587646484,
#  37.93333435058594,
#  38.20000076293945,
#  38.46666717529297,
#  38.599998474121094,
#  39.06666564941406,
#  39.266666412353516,
#  39.400001525878906,
#  39.66666793823242,
#  40.06666564941406,
#  40.400001525878906,
#  42.0,
#  42.13333511352539,
#  42.33333206176758,
#  42.79999923706055,
#  43.20000076293945,
#  43.599998474121094,
#  43.79999923706055,
#  43.93333435058594,
#  44.20000076293945,
#  44.33333206176758,
#  44.66666793823242,
#  44.86666488647461,
#  45.06666564941406,
#  45.266666412353516,
#  45.400001525878906,
#  45.86666488647461,
#  46.13333511352539,
#  48.400001525878906,
#  48.53333282470703,
#  48.66666793823242,
#  49.13333511352539,
#  49.400001525878906,
#  49.53333282470703,
#  49.86666488647461,
#  50.13333511352539,
#  50.33333206176758,
#  50.79999923706055,
#  50.93333435058594,
#  51.20000076293945,
#  51.46666717529297,
#  51.66666793823242,
#  51.79999923706055,
#  52.13333511352539,
#  52.46666717529297,
#  52.93333435058594,
#  53.20000076293945,
#  53.46666717529297,
#  53.733333587646484,
#  54.0,
#  54.266666412353516,
#  54.46666717529297,
#  54.79999923706055,
#  55.0,
#  55.266666412353516,
#  55.599998474121094,
#  55.86666488647461,
#  56.06666564941406,
#  56.33333206176758,
#  56.66666793823242,
#  56.93333435058594,
#  57.266666412353516,
#  57.53333282470703,
#  57.79999923706055,
#  58.0,
#  58.33333206176758,
#  58.599998474121094,
#  58.86666488647461,
#  59.13333511352539,
#  59.400001525878906,
#  59.66666793823242,
#  59.93333435058594,
#  60.20000076293945,
#  60.46666717529297,
#  60.733333587646484,
#  60.93333435058594,
#  61.266666412353516,
#  61.46666717529297,
#  61.79999923706055,
#  62.0,
#  62.33333206176758,
#  62.599998474121094,
#  62.86666488647461,
#  63.20000076293945,
#  63.599998474121094,
#  63.733333587646484,
#  64.33333587646484,
#  64.46666717529297,
#  64.66666412353516,
#  64.80000305175781,
#  65.06666564941406,
#  65.26667022705078,
#  65.5999984741211,
#  65.80000305175781,
#  65.93333435058594,
#  66.19999694824219,
#  66.5999984741211,
#  66.86666870117188,
#  67.19999694824219,
#  67.33333587646484,
#  71.73332977294922,
#  71.86666870117188,
#  73.0,
#  73.19999694824219,
#  74.93333435058594,
#  75.53333282470703,
#  76.46666717529297,
#  76.5999984741211,
#  77.19999694824219,
#  77.33333587646484,
#  77.53333282470703,
#  77.66666412353516,
#  78.26667022705078,
#  78.93333435058594,
#  79.13333129882812,
#  79.26667022705078,
#  79.53333282470703,
#  79.73332977294922,
#  80.13333129882812,
#  80.26667022705078,
#  80.46666717529297,
#  80.5999984741211,
#  80.80000305175781,
#  80.93333435058594,
#  81.06666564941406,
#  81.26667022705078,
#  81.4000015258789,
#  81.5999984741211,
#  81.80000305175781,
#  81.93333435058594,
#  82.06666564941406,
#  82.26667022705078,
#  82.4000015258789,
#  82.5999984741211,
#  82.80000305175781,
#  82.93333435058594,
#  83.06666564941406,
#  83.26667022705078,
#  83.4000015258789,
#  83.5999984741211,
#  83.73332977294922,
#  83.93333435058594,
#  84.06666564941406,
#  84.26667022705078,
#  84.4000015258789,
#  84.80000305175781,
#  84.93333435058594,
#  85.06666564941406,
#  85.33333587646484,
#  85.5999984741211,
#  85.73332977294922,
#  86.06666564941406,
#  86.4000015258789,
#  86.5999984741211,
#  86.80000305175781,
#  86.93333435058594,
#  87.06666564941406,
#  87.46666717529297,
#  87.5999984741211,
#  87.73332977294922,
#  88.06666564941406,
#  88.19999694824219,
#  88.4000015258789,
#  88.5999984741211,
#  88.93333435058594,
#  89.06666564941406,
#  89.26667022705078,
#  89.4000015258789,
#  89.53333282470703,
#  89.66666412353516,
#  89.93333435058594,
#  90.06666564941406,
#  90.19999694824219,
#  90.4000015258789,
#  90.53333282470703,
#  90.73332977294922,
#  90.86666870117188,
#  91.06666564941406,
#  91.26667022705078,
#  91.4000015258789,
#  91.53333282470703,
#  91.73332977294922,
#  91.86666870117188,
#  92.06666564941406,
#  92.19999694824219,
#  92.4000015258789,
#  92.5999984741211,
#  92.73332977294922,
#  92.93333435058594,
#  93.06666564941406,
#  93.26667022705078,
#  93.4000015258789,
#  93.53333282470703,
#  93.86666870117188,
#  94.06666564941406,
#  94.26667022705078,
#  94.4000015258789,
#  94.5999984741211,
#  94.93333435058594,
#  95.06666564941406,
#  95.19999694824219,
#  95.46666717529297,
#  95.66666412353516,
#  95.80000305175781,
#  96.06666564941406,
#  96.19999694824219,
#  96.33333587646484,
#  96.46666717529297,
#  96.66666412353516,
#  96.80000305175781,
#  97.13333129882812,
#  97.33333587646484,
#  97.80000305175781,
#  98.13333129882812,
#  98.26667022705078,
#  98.53333282470703,
#  98.66666412353516,
#  98.86666870117188,
#  99.06666564941406,
#  99.26667022705078,
#  99.4000015258789,
#  99.5999984741211,
#  99.86666870117188,
#  100.0,
#  100.26667022705078,
#  100.46666717529297,
#  100.66666412353516,
#  100.93333435058594,
#  101.19999694824219,
#  101.46666717529297,
#  101.66666412353516,
#  101.93333435058594,
#  102.06666564941406,
#  102.19999694824219,
#  102.66666412353516,
#  102.86666870117188,
#  103.0,
#  103.33333587646484,
#  103.80000305175781,
#  104.06666564941406,
#  104.26667022705078,
#  104.46666717529297,
#  104.66666412353516,
#  104.93333435058594,
#  105.06666564941406,
#  105.26667022705078,
#  105.46666717529297,
#  105.5999984741211,
#  105.80000305175781,
#  105.93333435058594,
#  106.4000015258789,
#  107.0,
#  107.4000015258789,
#  107.66666412353516,
#  108.19999694824219,
#  108.4000015258789,
#  108.53333282470703,
#  108.73332977294922,
#  108.93333435058594,
#  109.33333587646484,
#  109.5999984741211,
#  109.80000305175781,
#  110.06666564941406,
#  110.26667022705078,
#  110.5999984741211,
#  111.13333129882812,
#  111.46666717529297,
#  111.73332977294922,
#  111.86666870117188,
#  112.33333587646484,
#  112.46666717529297,
#  112.66666412353516,
#  112.86666870117188,
#  113.13333129882812,
#  113.26667022705078,
#  113.46666717529297,
#  113.86666870117188,
#  114.06666564941406,
#  114.4000015258789,
#  114.80000305175781,
#  115.06666564941406,
#  115.26667022705078,
#  115.4000015258789,
#  115.66666412353516,
#  116.13333129882812,
#  116.33333587646484,
#  116.66666412353516,
#  116.86666870117188,
#  117.13333129882812,
#  117.26667022705078,
#  117.46666717529297,
#  117.73332977294922,
#  118.0,
#  118.19999694824219,
#  118.73332977294922,
#  118.93333435058594,
#  119.4000015258789,
#  119.5999984741211,
#  120.19999694824219,
#  120.33333587646484,
#  120.80000305175781,
#  121.0,
#  121.13333129882812,
#  121.33333587646484,
#  121.46666717529297,
#  121.86666870117188,
#  122.06666564941406,
#  122.46666717529297,
#  122.66666412353516,
#  122.80000305175781,
#  123.06666564941406,
#  123.46666717529297,
#  123.73332977294922,
#  123.93333435058594,
#  124.06666564941406,
#  124.26667022705078,
#  124.53333282470703,
#  124.80000305175781,
#  125.13333129882812,
#  125.33333587646484,
#  125.53333282470703,
#  125.73332977294922,
#  126.4000015258789,
#  126.5999984741211,
#  126.73332977294922,
#  127.13333129882812,
#  127.26667022705078,
#  127.80000305175781,
#  128.06666564941406,
#  128.26666259765625,
#  128.39999389648438,
#  128.60000610351562,
#  129.39999389648438,
#  129.8000030517578,
#  129.93333435058594,
#  130.13333129882812,
#  130.3333282470703,
#  130.60000610351562,
#  130.73333740234375,
#  130.93333435058594,
#  131.26666259765625,
#  131.46665954589844,
#  131.8000030517578,
#  132.0,
#  132.3333282470703,
#  132.60000610351562,
#  132.93333435058594,
#  133.13333129882812,
#  133.39999389648438,
#  133.73333740234375,
#  134.1999969482422,
#  134.53334045410156,
#  135.0,
#  135.1999969482422,
#  135.3333282470703,
#  135.6666717529297,
#  135.8000030517578,
#  135.93333435058594,
#  136.06666564941406,
#  136.26666259765625,
#  136.46665954589844,
#  136.8000030517578,
#  137.13333129882812,
#  137.3333282470703,
#  137.6666717529297,
#  137.8000030517578,
#  138.0,
#  138.1999969482422,
#  138.3333282470703,
#  138.46665954589844,
#  138.6666717529297,
#  138.8000030517578,
#  138.93333435058594,
#  139.13333129882812,
#  139.46665954589844,
#  140.0,
#  140.46665954589844,
#  140.86666870117188,
#  141.06666564941406,
#  141.26666259765625,
#  141.53334045410156,
#  141.6666717529297,
#  141.8000030517578,
#  142.13333129882812,
#  142.53334045410156,
#  142.6666717529297,
#  142.8000030517578,
#  143.0,
#  143.1999969482422,
#  143.3333282470703,
#  143.46665954589844,
#  143.73333740234375,
#  143.86666870117188,
#  144.13333129882812,
#  144.3333282470703,
#  144.46665954589844,
#  144.6666717529297,
#  144.86666870117188,
#  145.0,
#  145.1999969482422,
#  145.3333282470703,
#  145.46665954589844,
#  145.60000610351562,
#  145.73333740234375,
#  145.86666870117188,
#  146.0,
#  146.13333129882812,
#  146.3333282470703,
#  146.46665954589844,
#  146.60000610351562,
#  146.73333740234375,
#  146.86666870117188,
#  147.0,
#  147.13333129882812,
#  147.3333282470703,
#  147.53334045410156,
#  147.6666717529297,
#  147.8000030517578,
#  147.93333435058594,
#  148.13333129882812,
#  148.3333282470703,
#  148.46665954589844,
#  148.6666717529297,
#  148.8000030517578,
#  149.0,
#  149.13333129882812,
#  149.3333282470703,
#  149.53334045410156,
#  149.6666717529297,
#  149.8000030517578,
#  150.0,
#  150.1999969482422,
#  150.3333282470703,
#  150.46665954589844,
#  150.60000610351562,
#  150.73333740234375,
#  150.93333435058594,
#  151.13333129882812,
#  151.26666259765625,
#  151.46665954589844,
#  151.60000610351562,
#  151.8000030517578,
#  152.8000030517578,
#  152.93333435058594,
#  154.60000610351562,
#  154.8000030517578,
#  155.0,
#  155.13333129882812,
#  155.3333282470703,
#  155.46665954589844,
#  155.60000610351562,
#  155.8000030517578,
#  156.0,
#  156.13333129882812,
#  156.26666259765625,
#  156.46665954589844,
#  156.60000610351562,
#  156.8000030517578,
#  157.0,
#  157.13333129882812,
#  157.3333282470703,
#  157.46665954589844,
#  157.6666717529297,
#  157.8000030517578,
#  158.0,
#  158.13333129882812,
#  158.39999389648438,
#  158.53334045410156,
#  158.73333740234375,
#  159.0,
#  159.13333129882812,
#  159.26666259765625,
#  159.46665954589844,
#  159.60000610351562,
#  159.8000030517578,
#  159.93333435058594,
#  160.06666564941406,
#  160.39999389648438,
#  160.60000610351562,
#  160.73333740234375,
#  160.93333435058594,
#  161.06666564941406,
#  161.26666259765625,
#  161.39999389648438,
#  161.60000610351562,
#  161.8000030517578,
#  161.93333435058594,
#  162.06666564941406,
#  162.26666259765625,
#  162.46665954589844,
#  162.60000610351562,
#  162.73333740234375,
#  162.93333435058594,
#  163.13333129882812,
#  163.26666259765625,
#  163.46665954589844,
#  163.60000610351562,
#  163.8000030517578,
#  163.93333435058594,
#  164.06666564941406,
#  164.26666259765625,
#  164.46665954589844,
#  164.60000610351562,
#  164.8000030517578,
#  164.93333435058594,
#  165.13333129882812,
#  165.26666259765625,
#  165.46665954589844,
#  165.60000610351562,
#  165.73333740234375,
#  165.93333435058594,
#  166.06666564941406,
#  166.26666259765625,
#  166.60000610351562,
#  166.73333740234375,
#  166.86666870117188,
#  167.06666564941406,
#  167.26666259765625,
#  167.46665954589844,
#  167.60000610351562,
#  167.73333740234375,
#  167.93333435058594,
#  168.06666564941406,
#  168.26666259765625,
#  168.46665954589844,
#  168.60000610351562,
#  168.73333740234375,
#  168.93333435058594,
#  169.06666564941406,
#  169.1999969482422,
#  169.3333282470703,
#  169.53334045410156,
#  169.73333740234375,
#  169.93333435058594,
#  170.06666564941406,
#  170.26666259765625,
#  170.39999389648438,
#  170.60000610351562,
#  170.73333740234375,
#  170.86666870117188,
#  171.06666564941406,
#  171.1999969482422,
#  171.39999389648438,
#  171.60000610351562,
#  171.73333740234375,
#  171.86666870117188,
#  172.06666564941406,
#  172.26666259765625,
#  172.39999389648438,
#  172.53334045410156,
#  172.73333740234375,
#  172.93333435058594,
#  173.06666564941406,
#  173.26666259765625,
#  173.53334045410156,
#  173.73333740234375,
#  173.93333435058594,
#  174.26666259765625,
#  174.60000610351562,
#  174.73333740234375,
#  175.1999969482422,
#  175.39999389648438,
#  175.53334045410156,
#  175.73333740234375,
#  175.93333435058594,
#  176.06666564941406,
#  176.26666259765625,
#  176.39999389648438,
#  176.60000610351562,
#  176.73333740234375,
#  176.86666870117188,
#  177.06666564941406,
#  177.26666259765625,
#  177.39999389648438,
#  177.53334045410156,
#  177.73333740234375,
#  177.93333435058594,
#  178.06666564941406,
#  178.26666259765625,
#  178.39999389648438,
#  178.53334045410156,
#  178.73333740234375,
#  178.93333435058594,
#  179.06666564941406,
#  179.1999969482422,
#  180.06666564941406,
#  181.1999969482422,
#  181.53334045410156,
#  181.73333740234375,
#  182.0,
#  182.26666259765625,
#  182.39999389648438,
#  182.93333435058594,
#  183.06666564941406,
#  183.26666259765625,
#  183.39999389648438,
#  183.73333740234375,
#  184.0,
#  184.13333129882812,
#  184.3333282470703,
#  184.46665954589844,
#  184.93333435058594,
#  185.1999969482422,
#  185.8000030517578,
#  186.1999969482422,
#  186.46665954589844,
#  186.6666717529297,
#  186.86666870117188,
#  187.6666717529297,
#  187.8000030517578,
#  187.93333435058594,
#  188.06666564941406,
#  188.1999969482422,
#  188.60000610351562,
#  189.1999969482422,
#  189.53334045410156,
#  189.86666870117188,
#  190.0,
#  190.46665954589844,
#  190.86666870117188,
#  191.1999969482422,
#  191.39999389648438,
#  191.8000030517578,
#  191.93333435058594,
#  192.06666564941406,
#  192.6666717529297,
#  193.0,
#  193.3333282470703,
#  193.73333740234375,
#  193.93333435058594,
#  194.39999389648438,
#  194.53334045410156,
#  194.73333740234375,
#  195.0,
#  195.13333129882812,
#  195.53334045410156,
#  195.6666717529297,
#  195.86666870117188,
#  196.13333129882812,
#  196.6666717529297,
#  196.8000030517578,
#  197.13333129882812,
#  197.3333282470703,
#  197.46665954589844,
#  197.73333740234375,
#  198.06666564941406,
#  198.73333740234375,
#  198.93333435058594,
#  199.26666259765625,
#  200.0,
#  200.1999969482422,
#  200.39999389648438,
#  200.53334045410156,
#  200.73333740234375,
#  201.13333129882812,
#  201.60000610351562,
#  201.73333740234375,
#  201.93333435058594,
#  202.1999969482422,
#  202.53334045410156,
#  202.73333740234375,
#  202.93333435058594,
#  203.26666259765625,
#  203.6666717529297,
#  204.13333129882812,
#  204.86666870117188,
#  205.26666259765625,
#  205.6666717529297,
#  206.0,
#  206.1999969482422,
#  206.53334045410156,
#  206.8000030517578,
#  207.06666564941406,
#  207.39999389648438,
#  207.60000610351562,
#  208.0,
#  208.1999969482422,
#  208.46665954589844,
#  208.86666870117188,
#  209.1999969482422,
#  209.60000610351562,
#  209.8000030517578,
#  210.0,
#  210.26666259765625,
#  210.60000610351562,
#  211.0,
#  211.1999969482422,
#  211.39999389648438,
#  211.53334045410156,
#  211.93333435058594,
#  212.3333282470703,
#  212.53334045410156,
#  212.8000030517578,
#  213.0,
#  213.39999389648438,
#  213.73333740234375,
#  214.13333129882812,
#  214.39999389648438,
#  214.53334045410156,
#  214.8000030517578,
#  215.26666259765625,
#  215.53334045410156,
#  215.73333740234375,
#  215.93333435058594,
#  216.06666564941406,
#  216.53334045410156,
#  216.73333740234375,
#  216.93333435058594,
#  217.06666564941406,
#  217.39999389648438,
#  217.73333740234375,
#  217.86666870117188,
#  218.26666259765625,
#  218.39999389648438,
#  218.6666717529297,
#  219.0,
#  219.1999969482422,
#  219.53334045410156,
#  219.86666870117188,
#  220.0,
#  220.13333129882812,
#  220.3333282470703,
#  220.60000610351562,
#  220.8000030517578,
#  221.0,
#  221.13333129882812,
#  221.60000610351562,
#  221.93333435058594,
#  222.3333282470703,
#  222.46665954589844,
#  222.60000610351562,
#  223.06666564941406,
#  223.26666259765625,
#  223.73333740234375,
#  223.93333435058594,
#  224.46665954589844,
#  225.06666564941406,
#  225.3333282470703,
#  225.46665954589844,
#  225.73333740234375,
#  225.86666870117188,
#  226.0,
#  226.1999969482422,
#  226.3333282470703,
#  226.53334045410156,
#  226.73333740234375,
#  226.86666870117188,
#  227.0,
#  227.1999969482422,
#  227.3333282470703,
#  227.53334045410156,
#  227.6666717529297,
#  227.86666870117188,
#  228.0,
#  228.1999969482422,
#  228.3333282470703,
#  228.46665954589844,
#  228.6666717529297,
#  228.86666870117188,
#  229.0,
#  229.1999969482422,
#  229.3333282470703,
#  229.46665954589844,
#  229.6666717529297,
#  229.86666870117188,
#  230.0,
#  230.1999969482422,
#  230.3333282470703,
#  230.53334045410156,
#  230.6666717529297,
#  230.86666870117188,
#  231.0,
#  231.1999969482422,
#  231.3333282470703,
#  231.46665954589844,
#  231.6666717529297,
#  231.8000030517578,
#  232.0,
#  232.13333129882812,
#  232.3333282470703,
#  232.53334045410156,
#  232.6666717529297,
#  232.86666870117188,
#  233.0,
#  233.1999969482422,
#  233.3333282470703,
#  233.53334045410156,
#  233.6666717529297,
#  233.86666870117188,
#  234.0,
#  234.1999969482422,
#  234.3333282470703,
#  234.53334045410156,
#  234.6666717529297,
#  234.86666870117188,
#  235.0,
#  235.1999969482422,
#  235.3333282470703,
#  235.53334045410156,
#  235.6666717529297,
#  235.8000030517578,
#  236.0,
#  236.13333129882812,
#  236.46665954589844,
#  236.60000610351562,
#  236.8000030517578,
#  236.93333435058594,
#  237.13333129882812,
#  237.26666259765625,
#  237.46665954589844,
#  237.6666717529297,
#  237.8000030517578,
#  238.0,
#  238.13333129882812,
#  238.26666259765625,
#  238.46665954589844,
#  238.6666717529297,
#  238.8000030517578,
#  238.93333435058594,
#  239.13333129882812,
#  239.26666259765625,
#  239.46665954589844,
#  239.60000610351562,
#  239.8000030517578,
#  239.93333435058594,
#  240.13333129882812,
#  240.26666259765625,
#  240.6666717529297,
#  240.8000030517578,
#  241.13333129882812,
#  241.3333282470703,
#  ...]

# %%
frames, fps = extract_frames(vid_file, frame_skip=10, downsample_factor=2)

_, video_peaks = detect_video_peaks(frames, fps)

# %%
video_peaks
# Out:
# [0.3333333432674408,
#  1.0,
#  1.6666666269302368,
#  2.6666667461395264,
#  3.6666667461395264,
#  4.333333492279053,
#  6.333333492279053,
#  7.333333492279053,
#  9.0,
#  10.0,
#  11.0,
#  13.0,
#  13.666666984558105,
#  15.0,
#  15.666666984558105,
#  16.33333396911621,
#  17.66666603088379,
#  18.33333396911621,
#  19.33333396911621,
#  20.33333396911621,
#  21.0,
#  22.33333396911621,
#  24.0,
#  25.33333396911621,
#  27.33333396911621,
#  28.33333396911621,
#  30.33333396911621,
#  31.0,
#  31.66666603088379,
#  32.66666793823242,
#  34.0,
#  35.33333206176758,
#  36.33333206176758,
#  37.66666793823242,
#  39.0,
#  39.66666793823242,
#  42.0,
#  43.0,
#  43.66666793823242,
#  45.33333206176758,
#  46.0,
#  46.66666793823242,
#  47.66666793823242,
#  49.0,
#  49.66666793823242,
#  50.33333206176758,
#  52.0,
#  53.33333206176758,
#  54.33333206176758,
#  55.33333206176758,
#  56.33333206176758,
#  57.0,
#  57.66666793823242,
#  59.0,
#  60.0,
#  61.66666793823242,
#  62.66666793823242,
#  63.33333206176758,
#  64.0,
#  64.66666412353516,
#  65.66666412353516,
#  66.66666412353516,
#  69.33333587646484,
#  71.0,
#  72.0,
#  72.66666412353516,
#  73.33333587646484,
#  74.0,
#  75.0,
#  76.66666412353516,
#  78.66666412353516,
#  79.33333587646484,
#  80.0,
#  81.33333587646484,
#  82.33333587646484,
#  84.0,
#  85.0,
#  85.66666412353516,
#  86.66666412353516,
#  89.66666412353516,
#  90.66666412353516,
#  92.33333587646484,
#  93.0,
#  95.0,
#  96.33333587646484,
#  98.33333587646484,
#  99.66666412353516,
#  100.66666412353516,
#  103.0,
#  103.66666412353516,
#  105.33333587646484,
#  106.0,
#  108.0,
#  108.66666412353516,
#  110.33333587646484,
#  111.66666412353516,
#  112.66666412353516,
#  113.66666412353516,
#  115.33333587646484,
#  116.0,
#  117.0,
#  117.66666412353516,
#  118.33333587646484,
#  119.0,
#  120.0,
#  121.0,
#  122.0,
#  123.66666412353516,
#  124.33333587646484,
#  125.33333587646484,
#  126.0,
#  127.0,
#  128.0,
#  129.6666717529297,
#  131.3333282470703,
#  132.3333282470703,
#  135.0,
#  137.0,
#  137.6666717529297,
#  138.6666717529297,
#  139.6666717529297,
#  142.0,
#  143.0,
#  143.6666717529297,
#  144.3333282470703,
#  145.3333282470703,
#  146.3333282470703,
#  147.0,
#  148.3333282470703,
#  149.0,
#  149.6666717529297,
#  150.6666717529297,
#  152.6666717529297,
#  153.3333282470703,
#  154.6666717529297,
#  155.6666717529297,
#  156.3333282470703,
#  158.0,
#  159.3333282470703,
#  160.3333282470703,
#  161.6666717529297,
#  162.3333282470703,
#  164.0,
#  165.3333282470703,
#  166.6666717529297,
#  167.3333282470703,
#  168.3333282470703,
#  169.0,
#  170.6666717529297,
#  172.3333282470703,
#  173.3333282470703,
#  174.3333282470703,
#  175.3333282470703,
#  176.0,
#  177.0,
#  178.0,
#  178.6666717529297,
#  181.0,
#  181.6666717529297,
#  183.3333282470703,
#  184.3333282470703,
#  185.6666717529297,
#  186.3333282470703,
#  187.0,
#  187.6666717529297,
#  189.3333282470703,
#  191.3333282470703,
#  192.3333282470703,
#  194.0,
#  195.6666717529297,
#  197.3333282470703,
#  199.0,
#  200.0,
#  201.6666717529297,
#  202.3333282470703,
#  204.0,
#  205.3333282470703,
#  206.6666717529297,
#  207.6666717529297,
#  208.6666717529297,
#  209.6666717529297,
#  210.3333282470703,
#  211.3333282470703,
#  212.6666717529297,
#  213.3333282470703,
#  214.3333282470703,
#  216.3333282470703,
#  217.0,
#  218.6666717529297,
#  219.3333282470703,
#  220.0,
#  221.0,
#  221.6666717529297,
#  222.3333282470703,
#  223.0,
#  223.6666717529297,
#  225.6666717529297,
#  227.0,
#  228.0,
#  229.3333282470703,
#  230.0,
#  231.6666717529297,
#  234.0,
#  236.0,
#  237.0,
#  238.3333282470703,
#  239.0,
#  240.0,
#  241.0,
#  241.6666717529297,
#  242.3333282470703,
#  243.0,
#  244.6666717529297,
#  245.6666717529297,
#  246.6666717529297,
#  247.6666717529297,
#  249.0]

# %%
_, video_peaks = detect_video_peaks(frames, fps)

# %%
video_peaks
# Out:
# [np.float64(2.6666666666666665),
#  np.float64(7.333333333333333),
#  np.float64(11.0),
#  np.float64(15.0),
#  np.float64(20.333333333333332),
#  np.float64(25.333333333333332),
#  np.float64(28.333333333333332),
#  np.float64(31.666666666666668),
#  np.float64(36.333333333333336),
#  np.float64(39.666666666666664),
#  np.float64(45.333333333333336),
#  np.float64(49.666666666666664),
#  np.float64(54.333333333333336),
#  np.float64(57.666666666666664),
#  np.float64(61.666666666666664),
#  np.float64(65.66666666666667),
#  np.float64(72.0),
#  np.float64(75.0),
#  np.float64(78.66666666666667),
#  np.float64(82.33333333333333),
#  np.float64(86.66666666666667),
#  np.float64(89.66666666666667),
#  np.float64(95.0),
#  np.float64(98.33333333333333),
#  np.float64(103.0),
#  np.float64(106.0),
#  np.float64(111.66666666666667),
#  np.float64(116.0),
#  np.float64(119.0),
#  np.float64(122.0),
#  np.float64(126.0),
#  np.float64(129.66666666666666),
#  np.float64(135.0),
#  np.float64(138.66666666666666),
#  np.float64(143.0),
#  np.float64(146.33333333333334),
#  np.float64(149.66666666666666),
#  np.float64(152.66666666666666),
#  np.float64(156.33333333333334),
#  np.float64(159.33333333333334),
#  np.float64(164.0),
#  np.float64(167.33333333333334),
#  np.float64(173.33333333333334),
#  np.float64(177.0),
#  np.float64(181.0),
#  np.float64(184.33333333333334),
#  np.float64(189.33333333333334),
#  np.float64(194.0),
#  np.float64(200.0),
#  np.float64(204.0),
#  np.float64(210.33333333333334),
#  np.float64(213.33333333333334),
#  np.float64(216.33333333333334),
#  np.float64(220.0),
#  np.float64(223.66666666666666),
#  np.float64(228.0),
#  np.float64(231.66666666666666),
#  np.float64(237.0),
#  np.float64(240.0),
#  np.float64(245.66666666666666),
#  np.float64(249.0)]

# %%
np.load('/work/users/s/m/smerrill/SymMV/video_peaks/-BjZmE2gtdo.npy')
# Out:
# array([  0.41708335,   2.91958332,   3.75375009,   6.67333364,
#          7.50750017,   8.75874996,  10.84416676,  11.67833328,
#         13.34666729,  15.43208408,  16.26625061,  17.51749992,
#         18.76875114,  20.02000046,  22.52250099,  24.19083405,
#         25.8591671 ,  27.52750015,  28.36166763,  34.20083618,
#         35.03499985,  40.04000092,  41.29125214,  42.12541962,
#         43.79375076,  45.87916946,  47.13041687,  48.38166809,
#         49.63291931,  51.30125046,  55.05500031,  56.72333527,
#         57.55750275,  60.47708511,  62.97958374,  63.81375122,
#         66.7333374 ,  68.40167236,  70.06999969,  70.90416718,
#         71.73833466,  72.57250214,  73.40666962,  75.07500458,
#         76.3262558 ,  77.16041565,  77.99458313,  80.49708557,
#         82.16542053,  83.83375549,  85.91916656,  88.00458527,
#         88.83875275,  90.50708771,  92.59250641,  93.84375   ,
#         94.67791748,  95.51208496,  97.18041992,  98.0145874 ,
#         99.26583862, 100.1000061 , 102.18541718, 104.27083588,
#        108.85875702, 110.94416809, 112.61250305, 113.44667053,
#        115.53208923, 116.36625671, 117.61750031, 118.86875153,
#        119.70291901, 121.37125397, 122.62250519, 123.45667267,
#        126.37625122, 128.46166992, 129.71292114, 132.63250732,
#        135.55209351, 136.38626099, 137.63749695, 138.88874817,
#        140.97416687, 142.22541809, 143.89375305, 145.14500427,
#        145.97917175, 147.23042297, 148.48167419, 150.15000916,
#        150.98417664, 152.6525116 , 153.90374756, 154.73791504,
#        155.98916626, 158.4916687 , 160.5770874 , 161.82833862,
#        163.07958984, 163.91375732, 165.16500854, 166.41625977,
#        167.25042725, 168.08459473, 169.75292969, 170.58708191,
#        171.42124939, 173.50666809, 175.17500305, 176.42625427,
#        177.26042175, 179.76292419, 182.26542664, 183.09959412,
#        184.35084534, 187.27041626, 191.44125366, 193.10958862,
#        193.9437561 , 194.77792358, 195.61209106, 196.44625854,
#        197.28042603, 198.11459351, 200.20001221, 201.86834717,
#        203.53666687, 204.37083435, 206.03916931, 206.87333679,
#        208.12458801, 209.37583923, 210.21000671, 211.04417419,
#        213.54667664, 215.2150116 , 218.13459778, 219.38583374,
#        221.88833618, 224.39083862, 227.72750854, 229.81292725,
#        232.31542969])

# %%
pd.read_csv('/work/users/s/m/smerrill/Youtube8m/flow/ranks_400.csv').sort_values('vid')
# Out:
#               vid              ranks                                 segments  \
# 1253  --SM0mwlHjY  [7 5 1 3 4 8 2 6]    [0, 19, 42, 52, 74, 85, 95, 123, 133]
# 1036  -63Da0zOWWo  [8 5 2 1 6 3 4 7]    [0, 16, 32, 42, 52, 77, 94, 109, 133]
# 623   -6jwBiRsWP0  [4 8 6 1 5 2 7 3]    [0, 23, 42, 58, 69, 82, 96, 113, 133]
# 53    -AICqjB56gE  [4 8 1 5 7 2 6 3]   [0, 18, 28, 51, 76, 86, 108, 118, 133]
# 1248  -DNnvpMjq9g  [8 7 1 5 4 2 3 6]    [0, 16, 32, 47, 67, 77, 87, 109, 133]
# ...           ...                ...                                      ...
# 841   zn2m84TeOps  [7 2 4 6 1 5 8 3]   [0, 11, 23, 48, 60, 79, 105, 115, 133]
# 76    znP-6iEYeF0  [8 7 2 6 3 4 5 1]    [0, 10, 23, 37, 47, 81, 94, 108, 133]
# 292   znsikHT6WRo  [4 7 3 8 2 5 1 6]    [0, 18, 28, 44, 56, 69, 84, 112, 133]
# 682   zpHtixFUX6o  [5 7 3 6 1 2 4 8]   [0, 22, 32, 54, 64, 74, 106, 118, 133]
# 155   zxgnCCXnkbA  [4 7 3 1 5 6 8 2]  [0, 19, 46, 56, 71, 101, 111, 123, 133]
#
#       top_start     top_end  bottom_start  bottom_end
# 1253       42.0   52.000000          85.0   95.000000
# 1036       42.0   52.000000           0.0   16.000000
# 623        58.0   69.000000          23.0   42.000000
# 53         28.0   51.000000          18.0   28.000000
# 1248       32.0   47.000000           0.0   16.000000
# ...         ...         ...           ...         ...
# 841        60.0   79.000000         105.0  115.000000
# 76        108.0  133.333333           0.0   10.000000
# 292        84.0  112.000000          44.0   56.000000
# 682        64.0   74.000000         118.0  133.333333
# 155        56.0   71.000000         111.0  123.000000
#
# [1541 rows x 7 columns]

# %%
test_path = '/work/users/s/m/smerrill/Youtube8m/test_resnet.csv'
vid_feature_dir = '/work/users/s/m/smerrill/Youtube8m/resnet/resnet101'
aud_feature_dir = '/work/users/s/m/smerrill/Youtube8m/vggish'
flow_dir = '/work/users/s/m/smerrill/Youtube8m/flow'

# Open and read the CSV file
with open(test_path, 'r') as file:
    lines = file.readlines()

lines = [line.strip() for line in lines]

# %%
def get_meta_df(video_feature_path, audio_feature_path, flow_rank_file, max_seq_len, test_file=None):
    def parse_ranks_str(ranks_str):
        # Remove tuple and quotes, then extract numbers
        cleaned = ranks_str.strip("(),'")  # removes parentheses, commas, quotes
        return list(map(int, cleaned.strip('[]').split()))


    video_files = os.listdir(video_feature_path)
    audio_files = os.listdir(audio_feature_path)

    video_file_map = {filename.split('.')[0]: os.path.join(video_feature_path, filename) for filename in video_files }
    audio_file_map = {filename.split('.')[0]: os.path.join(audio_feature_path, filename) for filename in audio_files}
    
    flow_ranks = pd.read_csv(flow_rank_file)
    flow_ranks_dict = dict(zip(flow_ranks['vid'], flow_ranks['ranks']))
    
    vid_df = pd.DataFrame(list(video_file_map.items()), columns=['vid', 'vid_filename'])
    aud_df = pd.DataFrame(list(audio_file_map.items()), columns=['vid', 'aud_filename'])
    flow_ranks = pd.read_csv(flow_rank_file)[['vid', 'ranks', 'segments']]

    df = vid_df.merge(aud_df, on='vid').merge(flow_ranks, on='vid')

    df['ranks'] = df['ranks'].apply(
        lambda x: parse_ranks_str(x) if isinstance(x, str) else list(map(int, x)))

    # drop entire videos who's max sequence length doesn't comply
    df = df[df['segments'].apply(lambda s: max(np.diff(ast.literal_eval(s))) <= max_seq_len)].reset_index(drop=True)

    if test_file:
        # Open and read the CSV file
        with open(test_path, 'r') as file:
            lines = file.readlines()

        vids = [line.split('.')[0] for line in lines]

    return df
import ast

test = get_meta_df(vid_feature_dir, \
                  aud_feature_dir, \
                  '/work/users/s/m/smerrill/Youtube8m/flow/ranks.csv',\
                  200)

# %%
test
# Out:
#                vid                                       vid_filename  \
# 0      --81RtUMW1w  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 1      --LxRKErLk8  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 2      --SM0mwlHjY  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 3      --pYDRqWOhk  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 4      --v2_eyl-xg  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# ...            ...                                                ...
# 15668  zy65W7be-T4  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 15669  zzHj0MMhZRM  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 15670  zzWPUaKVg7c  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 15671  zzWZchxa_Ws  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 15672  zzo9y1cRKFo  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
#
#                                             aud_filename  \
# 0      /work/users/s/m/smerrill/Youtube8m/vggish/--81...
# 1      /work/users/s/m/smerrill/Youtube8m/vggish/--Lx...
# 2      /work/users/s/m/smerrill/Youtube8m/vggish/--SM...
# 3      /work/users/s/m/smerrill/Youtube8m/vggish/--pY...
# 4      /work/users/s/m/smerrill/Youtube8m/vggish/--v2...
# ...                                                  ...
# 15668  /work/users/s/m/smerrill/Youtube8m/vggish/zy65...
# 15669  /work/users/s/m/smerrill/Youtube8m/vggish/zzHj...
# 15670  /work/users/s/m/smerrill/Youtube8m/vggish/zzWP...
# 15671  /work/users/s/m/smerrill/Youtube8m/vggish/zzWZ...
# 15672  /work/users/s/m/smerrill/Youtube8m/vggish/zzo9...
#
#                           ranks                                    segments
# 0      [3, 6, 2, 4, 1, 8, 5, 7]     [0, 35, 49, 68, 87, 103, 113, 123, 146]
# 1      [6, 3, 5, 2, 4, 7, 1, 8]   [0, 10, 93, 129, 155, 165, 175, 232, 242]
# 2      [8, 3, 6, 4, 7, 1, 5, 2]    [0, 42, 52, 95, 125, 144, 181, 202, 232]
# 3      [3, 7, 2, 6, 4, 1, 5, 8]   [0, 70, 82, 115, 130, 193, 205, 244, 254]
# 4      [7, 3, 6, 1, 4, 2, 5, 8]  [0, 21, 178, 189, 199, 280, 308, 318, 328]
# ...                         ...                                         ...
# 15668  [5, 8, 7, 2, 4, 3, 1, 6]    [0, 24, 52, 93, 103, 141, 187, 207, 232]
# 15669  [5, 3, 8, 2, 7, 1, 4, 6]  [0, 82, 104, 114, 125, 155, 165, 235, 278]
# 15670  [6, 4, 1, 2, 5, 3, 7, 8]    [0, 17, 33, 47, 112, 124, 139, 149, 159]
# 15671  [6, 2, 7, 1, 5, 3, 4, 8]    [0, 51, 75, 86, 107, 145, 193, 307, 317]
# 15672  [3, 5, 8, 4, 6, 1, 2, 7]       [0, 13, 26, 39, 49, 64, 82, 169, 186]
#
# [15673 rows x 5 columns]

# %%
with open(test_path, 'r') as file:
    lines = file.readlines()

vids = [line.split('.')[0] for line in lines]

# %%
test[test.vid.isin(vids)].reset_index(drop=True)
# Out:
#                vid                                       vid_filename  \
# 2      --SM0mwlHjY  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 37     -63Da0zOWWo  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 38     -6jwBiRsWP0  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 56     -AICqjB56gE  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 65     -DNnvpMjq9g  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# ...            ...                                                ...
# 15624  zn2m84TeOps  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 15628  znP-6iEYeF0  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 15629  znsikHT6WRo  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 15633  zpHtixFUX6o  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
# 15666  zxgnCCXnkbA  /work/users/s/m/smerrill/Youtube8m/resnet/resn...
#
#                                             aud_filename  \
# 2      /work/users/s/m/smerrill/Youtube8m/vggish/--SM...
# 37     /work/users/s/m/smerrill/Youtube8m/vggish/-63D...
# 38     /work/users/s/m/smerrill/Youtube8m/vggish/-6jw...
# 56     /work/users/s/m/smerrill/Youtube8m/vggish/-AIC...
# 65     /work/users/s/m/smerrill/Youtube8m/vggish/-DNn...
# ...                                                  ...
# 15624  /work/users/s/m/smerrill/Youtube8m/vggish/zn2m...
# 15628  /work/users/s/m/smerrill/Youtube8m/vggish/znP-...
# 15629  /work/users/s/m/smerrill/Youtube8m/vggish/znsi...
# 15633  /work/users/s/m/smerrill/Youtube8m/vggish/zpHt...
# 15666  /work/users/s/m/smerrill/Youtube8m/vggish/zxgn...
#
#                           ranks                                    segments
# 2      [8, 3, 6, 4, 7, 1, 5, 2]    [0, 42, 52, 95, 125, 144, 181, 202, 232]
# 37     [4, 3, 6, 1, 7, 2, 5, 8]  [0, 52, 109, 129, 140, 155, 210, 230, 242]
# 38     [4, 8, 5, 3, 6, 1, 2, 7]     [0, 23, 42, 58, 96, 113, 145, 209, 223]
# 56     [4, 8, 2, 6, 3, 7, 1, 5]     [0, 18, 28, 76, 86, 143, 153, 169, 183]
# 65     [7, 5, 2, 3, 1, 4, 6, 8]   [0, 16, 32, 109, 147, 157, 188, 198, 210]
# ...                         ...                                         ...
# 15624  [7, 1, 4, 6, 3, 5, 2, 8]    [0, 11, 23, 79, 115, 134, 177, 213, 246]
# 15628  [8, 7, 5, 3, 4, 2, 6, 1]     [0, 10, 23, 81, 94, 108, 130, 228, 238]
# 15629  [3, 5, 7, 4, 1, 6, 2, 8]     [0, 18, 44, 56, 87, 112, 161, 253, 263]
# 15633  [5, 3, 6, 1, 2, 7, 4, 8]     [0, 28, 54, 64, 74, 118, 143, 190, 204]
# 15666  [3, 6, 1, 4, 5, 7, 2, 8]    [0, 19, 46, 71, 101, 111, 124, 191, 207]
#
# [1564 rows x 5 columns]
